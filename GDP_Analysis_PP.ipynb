# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
gdp=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\GDP_2020.csv").set_index("Country Name").iloc[:,4:]

# %%
gdp.head(2)
# Out:
#                                      1961          1962          1963  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  1.970954e+10  2.147872e+10  2.571501e+10
#
#                                      1964          1965          1966  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  2.351080e+10  2.679160e+10  2.913154e+10
#
#                                      1967          1968          1969  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  3.015183e+10  3.285380e+10  3.771765e+10
#
#                                      1970  ...          2011          2012  \
# Country Name                               ...
# Aruba                                 NaN  ...  2.549721e+09  2.534637e+09
# Africa Eastern and Southern  4.028726e+10  ...  9.427110e+11  9.498490e+11
#
# ...

# %%
agri=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Agri_2020.csv").set_index("Country Name").iloc[:,4:]
exports=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Exports_2020.csv").set_index("Country Name").iloc[:,4:]
final_consumption=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Final_Consumption_2020.csv").set_index("Country Name").iloc[:,4:]
gdp_growth=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\GDP_Growth_2020.csv").set_index("Country Name").iloc[:,4:]
gross_capital_formation=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Gross_Capital_Formation_2020.csv").set_index("Country Name").iloc[:,4:]
gross_saving=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Gross_Saving_2020.csv").set_index("Country Name").iloc[:,4:]
imports=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Imports_2020.csv").set_index("Country Name").iloc[:,4:]
industry=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Industry_2020.csv").set_index("Country Name").iloc[:,4:]
manufacturing=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Manufacturing_2020.csv").set_index("Country Name").iloc[:,4:]
population=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Population_2020.csv").set_index("Country Name").iloc[:,4:]
service=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\Service_2020.csv").set_index("Country Name").iloc[:,4:]

# %%
i="India"
year=np.array(gdp.loc[i].index).astype(np.int32)
ch="China"
bn="Bangladesh"
pk="Pakistan"

# %%
gdp.head()
# Out:
#                                      1961          1962          1963  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  1.970954e+10  2.147872e+10  2.571501e+10
# Afghanistan                  5.488889e+08  5.466667e+08  7.511112e+08
# Africa Western and Central   1.112805e+10  1.194335e+10  1.267652e+10
# Angola                                NaN           NaN           NaN
#
#                                      1964          1965          1966  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  2.351080e+10  2.679160e+10  2.913154e+10
# Afghanistan                  8.000000e+08  1.006667e+09  1.400000e+09
# Africa Western and Central   1.383858e+10  1.486247e+10  1.583285e+10
# Angola                                NaN           NaN           NaN
#
#                                      1967          1968          1969  \
# Country Name
# ...

# %%
gdp.loc[["India"]]
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,gdp.loc["India"])
plt.plot(year,gdp.loc["India"],"o")
plt.title("Indian Economy 1960 to 2020")
plt.show()
print("Value of Indian Economy is",((gdp.loc["India"]).max())/1000000000000, "Trillion USD")
# Out:
# Value of Indian Economy is 2.8705 Trillion USD

# %% [markdown]
# A steeply growing Indian economy began to slow down in 2007-08 after reaching a GDP
# growth of 9.8 per cent in the last quarter of 2006-07.
#
# The global Financial crisis has hit India through a “sudden stop” of capital inflows and a collapse
# of both external and domestic demand. The growth of the economy dropped to 6.7 per
# cent in 2008 declined further in 2009-10
#
# Pandemic was bad for world economy and especially hard hitting for indian ecomony which shows steep fall especially in the begining of 2020 which shows further slowdown after a very small correction.

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,gdp_growth.loc[i], color="blue",label="INDIA")
plt.plot(year,gdp_growth.loc[i],"o")
plt.title("Indian Economy growth 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# Famine of 1965 and wars of 1965, 1971 shows negative impact on indian Economy.
#
# In 1979-80, the Indian economy faced a double whammy with a severe drought gripping most of the country and crude oil prices almost doubling due to supply disruptions because of the Iranian revolution against the state’s monarch.
#
# The Current Account Deficit in 1990-91 massively weakened the ability to finance deficit. The 1991 Indian economic crisis was an economic crisis in India resulting from a balance of payments deficit due to excess reliance on imports and other external factors.
#
# Indian economy began to slow down in 2007-08 after reaching a GDP growth of 9.8 per cent in the last quarter of 2006-07.
# The global Financial crisis has hit India through a “sudden stop” of capital inflows and a collapse of both external and domestic demand. The growth of the economy dropped in 2008 declined further in 2009-10
#
# Pandemic was bad for world economy and especially hard hitting for indian ecomony which shows steep fall especially in the begining of 2020 which shows further slowdown after a very small correction.

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,gdp_growth.loc[i], color="blue",label="REPUBLIC OF INDIA")
plt.plot(year,gdp_growth.loc[i],"o")
plt.plot(year,gdp_growth.loc[ch], color="red",label="PEOPLES REPUBLIC OF CHINA")
plt.plot(year,gdp_growth.loc[ch],"*")
plt.plot(year,gdp_growth.loc[bn], color="green",label="ISLAMIC REPUBLIC OF BANGLADESH")
plt.plot(year,gdp_growth.loc[bn],"*")
plt.title("Indian Vs China Vs Bangladesh Economy 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# China's GDP Growth has been stable with some double digit growth in past. The growth been possitive but declining after 2008 economic slowdown. The recent decline due to pandemic is visible.
#
# Bangladesh's GDP growt has been slightly below India's till 2010. After 2010, the growth slope has increased. Effect of pandemic and 1980's global econimic slowdown is visible.
#
# The effect of pandemic is visible on most of the world economies, however the impact on indian economy is especially bad.

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,gdp.loc[i], color="blue",label="REPUBLIC OF INDIA")
plt.plot(year,gdp.loc[i],"o")
plt.plot(year,gdp.loc[ch], color="red",label="PEOPLES REPUBLIC OF CHINA")
plt.plot(year,gdp.loc[ch],"*")
plt.plot(year,gdp.loc[bn], color="green",label="ISLAMIC REPUBLIC OF BANGLADESH")
plt.plot(year,gdp.loc[bn],"+")
plt.title("Indian Vs China Economy 1960 to 2020")
plt.legend()
plt.show()
print("Value of Indian Economy is",((gdp.loc[i]).max())/1000000000000, "Trillion USD")
print("Value of China Economy is",((gdp.loc[pk]).max())/1000000000000, "Trillion USD")
print("Value of Bangladesh Economy is",((gdp.loc[bn]).max())/1000000000000, "Trillion USD")
# Out:
# Value of Indian Economy is 2.8705 Trillion USD
# Value of China Economy is 0.314568 Trillion USD
# Value of Bangladesh Economy is 0.323057 Trillion USD

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,agri.loc[i], color="blue",label="REPUBLIC OF INDIA")
plt.plot(year,agri.loc[i],"o")
plt.plot(year,agri.loc[ch], color="red",label="PEOPLES REPUBLIC OF CHINA")
plt.plot(year,agri.loc[ch],"*")
plt.plot(year,agri.loc[bn], color="green",label="ISLAMIC REPUBLIC OF BANGLADESH")
plt.plot(year,agri.loc[bn],"*")
plt.title("Indian Vs China Vs Bangladesh Agriculture Sector Growth 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# Indian Agriculture sector growth in comparision to China and Bangladesh has been inconsistent, there has been highs and lows at both extents. There had been underperformances as recent as 2010/11 and 2014/15.
#
# Bangladesh shows a stable and possitive trend on the ending note. china as well remains stable after some double digit growth in past.
#
# Dont see any impact of pandemic.

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,service.loc[i], color="blue",label="REPUBLIC OF INDIA")
plt.plot(year,service.loc[i],"o")
plt.plot(year,service.loc[ch], color="red",label="PEOPLES REPUBLIC OF CHINA")
plt.plot(year,service.loc[ch],"*")
plt.plot(year,service.loc[bn], color="green",label="ISLAMIC REPUBLIC OF BANGLADESH")
plt.plot(year,service.loc[bn],"*")
plt.title("Indian Vs China Vs Bangladesh Service Sector Growth 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# China's service sector growth has been humongous in past decades and has stablized with small correction.
# Bangladesh had been slow and steady with a possitive growth trend.
#
# Effect of pandemic is visible however the inpact on indian sector is most.
#
# Indian service sector did well other than minor drops during recessions and slow downs, the impact of pandemic is huge.

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,industry.loc[i], color="blue",label="REPUBLIC OF INDIA")
plt.plot(year,industry.loc[i],"o")
plt.plot(year,industry.loc[ch], color="red",label="PEOPLES REPUBLIC OF CHINA")
plt.plot(year,industry.loc[ch],"*")
plt.plot(year,industry.loc[bn], color="green",label="ISLAMIC REPUBLIC OF BANGLADESH")
plt.plot(year,industry.loc[bn],"*")
plt.title("Indian Vs China Vs Bangladesh Industrial Growth 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# China has shown heavy growth and has stabilized possitively above india.
#
# Bangladesh has done considerably well and has shown upwards trend towards 2019, the dro due to pandemic is visible. Has done better tha India in recent few year on year growth.
#
# India has shown downward trend due to global reasons.

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,exports.loc[i], color="blue",label="REPUBLIC OF INDIA")
plt.plot(year,exports.loc[i],"o")
plt.plot(year,exports.loc[ch], color="red",label="PEOPLES REPUBLIC OF CHINA")
plt.plot(year,exports.loc[ch],"*")
plt.plot(year,exports.loc[bn], color="green",label="ISLAMIC REPUBLIC OF BANGLADESH")
plt.plot(year,exports.loc[bn],"*")
plt.title("Indian Vs China Vs Bangladesh Export Growth Trend 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# Effect of pandemic is clearly visible in the export trends.

# %%
i="India"
country=pd.concat([gdp.loc[i],exports.loc[i],agri.loc[i],final_consumption.loc[i],
                   gdp_growth.loc[i],gross_capital_formation.loc[i],
                   imports.loc[i],gross_saving.loc[i],industry.loc[i],manufacturing.loc[i],population.loc[i],
                   service.loc[i]],1)
col=['gdp','exports','agriculture','final_consumption','gdp_growth','gross_capital_formation','imports',
     'gross_saving','industry','manufacturing','population','service']
country.columns=col

# %%
country.head()
# Out:
#                gdp    exports  agriculture  final_consumption  gdp_growth  \
# 1961  3.923244e+10  -0.185873     0.084207           2.068121    3.722743
# 1962  4.216148e+10  -0.579831    -1.989099           2.555346    2.931128
# 1963  4.842192e+10   8.404078     2.339252           5.179191    5.994353
# 1964  5.648029e+10  -6.512050     9.224275           5.840048    7.452950
# 1965  5.955485e+10 -13.864176   -11.042197           0.931947   -2.635770
#
#       gross_capital_formation    imports  gross_saving  industry  \
# 1961                -1.043266  -9.755901           NaN  6.712677
# 1962                14.196934   3.909215           NaN  7.072028
# 1963                 7.415240   3.391989           NaN  9.447275
# 1964                10.403833   3.379743           NaN  6.479270
# 1965                10.382610 -11.056208           NaN  4.525377
#
#       manufacturing   population   service
# 1961       8.539505  459642166.0  4.901665
# ...

# %%
plt.figure(figsize=(16,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,country["gdp_growth"],color="red",label="GDP Growth")
plt.plot(year,country["gdp_growth"],"o",color="r")
plt.plot(year,country["agriculture"],"*",color="green")
plt.plot(year,country["agriculture"],color="green",label="Agriculture Growth")
plt.title("Comparision of GDP Growth and Agricultural Growth")
plt.legend()
plt.show()

# %% [markdown]
# Indian Economy has been closely =lined with agriculture growth till 1992, after 1992 the agricultyure sector's direct on impact on economy of the country has reduced especially during past 2 decades the ecomomy is more sevice and manufacturing centric.
#
# Negative impact of drought during 1965 and 1979/80's is clearly visible.
#
# 1967-68 saw its best ever growth then, due to the Green revolution envisioned by Former PM Shastry which was led by MS Swaminathan. A favourable monsoon as well helped the agriculture.

# %%
plt.figure(figsize=(16,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,country["gdp_growth"],color="red",label="GDP Growth")
plt.plot(year,country["gdp_growth"],"o",color="r")
plt.plot(year,country["industry"],"*",color="brown")
plt.plot(year,country["industry"],color="brown",label="Industrial Growth")
plt.title("Comparision of GDP Growth and Industrial Growth")
plt.legend()
plt.show()

# %% [markdown]
# GDP growth and Indistrial growth has been closely associates since early 1980s.The effect is still valid as it shows a relative fall on global reasons in recent years and nosedive during 2019 and 2020.

# %%
plt.figure(figsize=(16,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,country["gdp_growth"],color="red",label="GDP Growth")
plt.plot(year,country["gdp_growth"],"o",color="r")
plt.plot(year,country["manufacturing"],"*",color="orange")
plt.plot(year,country["manufacturing"],color="orange",label="Manufacturing Growth")
plt.legend()
plt.title("Comparision of GDP Growth and Manufacturing")
plt.show()

# %% [markdown]
# GDP growth and Manufacturing sector growth has been associates since early 1980s.
# The effect is still valid as it shows a relative fall on global reasons in recent years and nosedive during 2019 and 2020.
# 1980's global slowdown and 2008's recession has caused negative impact. Forst half of 90's and mid 2000 has been very productive.

# %%
plt.figure(figsize=(16,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,country["gdp_growth"],color="red",label="GDP Growth")
plt.plot(year,country["gdp_growth"],"o",color="r")
plt.plot(year,country["imports"],"*",color="blue")
plt.plot(year,country["imports"],color="blue",label="Import Trend")
plt.plot(year,country["exports"],"*",color="green")
plt.plot(year,country["exports"],color="green",label="Export Trend")
plt.legend()
plt.title("Comparision of GDP Growth With Export and Import Growth Trend")
plt.show()

# %% [markdown]
# Export and import shows no visible impact on the GDP Growth, other than the drop in both during pandemic.

# %%
plt.figure(figsize=(16,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,country["gdp_growth"],color="red",label="GDP Growth")
plt.plot(year,country["gdp_growth"],"o",color="r")
plt.plot(year,country["service"],"*",color="aqua")
plt.plot(year,country["service"],color="aqua",label="Service Industry Growth")
plt.legend()
plt.title("Comparision of GDP Growth and Service Industry's Growth")
plt.show()

# %% [markdown]
# GDP growth and service sector growth has been associated closely after late 90s and early 2000.
# The effect is still valid, it shows a relative fall on global reasons in recent years and nosedive during 2019 and 2020.
# 1980's global slowdown and 2008's recession has caused negative impact. Its seen as one of the major factors along with industrial and manufacturing growth which is driving the economy today.

# %%
plt.figure(figsize=(15,10))
sn.heatmap((country.drop(["gdp"],1)).corr(),annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Based on correlation heatmap. Industrial growth and sevice sector shows more inclined towrds the gdp growth as driving factors. Manufacturing and Agriculture also comes close second. In the recent decades Agriculture sector's contrinbution has reduced in driving national economy.
#
# As a known fact, final consumption shows high degree of correlation with the GDP Growth.

# %%
corr_full=country.drop('gdp',1).corr().iloc[3].reset_index().iloc[1:,:]
corr_full=corr_full.set_index('index')
corr_full.index.names=['Indicators']
corr_full
# Out:
#                          gdp_growth
# Indicators
# agriculture                0.649251
# final_consumption          0.880496
# gdp_growth                 1.000000
# gross_capital_formation    0.435306
# imports                    0.239381
# gross_saving               0.186553
# industry                   0.715466
# manufacturing              0.615444
# population                 0.250361
# service                    0.725487

# %%
corr_1991=country[country.index.astype(np.int32)>=1991].drop('gdp',1).corr().iloc[3].reset_index().iloc[1:,:]
corr_1991=corr_1991.set_index('index')
corr_1991.index.names=['Indicators']
corr_1991
# Out:
#                          gdp_growth
# Indicators
# agriculture                0.240928
# final_consumption          0.885066
# gdp_growth                 1.000000
# gross_capital_formation    0.649703
# imports                    0.362997
# gross_saving               0.243494
# industry                   0.824451
# manufacturing              0.735070
# population                -0.064076
# service                    0.860967

# %%
corr_2004=country[country.index.astype(np.int32)>=2004].drop('gdp',1).corr().iloc[3].reset_index().iloc[1:,:]
corr_2004=corr_2004.set_index('index')
corr_2004.index.names=['Indicators']
corr_2004
# Out:
#                          gdp_growth
# Indicators
# agriculture                0.051477
# final_consumption          0.908193
# gdp_growth                 1.000000
# gross_capital_formation    0.670685
# imports                    0.408803
# gross_saving               0.345177
# industry                   0.880268
# manufacturing              0.803390
# population                -0.451977
# service                    0.938752

# %%
corr_2014=country[country.index.astype(np.int32)>=2014].drop('gdp',1).corr().iloc[3].reset_index().iloc[1:,:]
corr_2014=corr_2014.set_index('index')
corr_2014.index.names=['Indicators']
corr_2014
# Out:
#                          gdp_growth
# Indicators
# agriculture               -0.056508
# final_consumption          0.986750
# gdp_growth                 1.000000
# gross_capital_formation    0.887150
# imports                    0.643981
# gross_saving               0.418270
# industry                   0.931911
# manufacturing              0.875855
# population                -0.744692
# service                    0.976547

# %% [markdown]
# The Above analysis suggests the relationship between agriculture and gdp growth has been fading over the years and in recent times it hasnt shown any considerable relation.
#
# On Other hand Growing consumption has had possitive impact on the economy.
#
# Manufactiring, industry and service sector are the drivers of economy for the past few decades.
#
# Population is showing strong negative correlation with the gdp growth.

# %%
country3=country.copy()
country3=country3.reset_index()

# %%
conditions = [
    (country3["index"].astype(np.int32)<1964),
    ((country3["index"].astype(np.int32)>=2004) & (country3["index"].astype(np.int32)<=2014)),
    (country3["index"].astype(np.int32)>2014),
    ((country3["index"].astype(np.int32)>=1964) & (country3["index"].astype(np.int32)<=1966)),
    ((country3["index"].astype(np.int32)>=1991) & (country3["index"].astype(np.int32)<=1996)),
    ((country3["index"].astype(np.int32)>=1966) & (country3["index"].astype(np.int32)<=1977)),
    ((country3["index"].astype(np.int32)>=1980) & (country3["index"].astype(np.int32)<=1984)),
    ((country3["index"].astype(np.int32)>1984) & (country3["index"].astype(np.int32)<=1989))
]

# %%
values = ["jln","mms","modi","lbs","rao","indira","indira","rajiv"]

# %%
country3["pm"]=np.select(conditions,values)

# %%
country3.head()
# Out:
#   index           gdp    exports  agriculture  final_consumption  gdp_growth  \
# 0  1961  3.923244e+10  -0.185873     0.084207           2.068121    3.722743
# 1  1962  4.216148e+10  -0.579831    -1.989099           2.555346    2.931128
# 2  1963  4.842192e+10   8.404078     2.339252           5.179191    5.994353
# 3  1964  5.648029e+10  -6.512050     9.224275           5.840048    7.452950
# 4  1965  5.955485e+10 -13.864176   -11.042197           0.931947   -2.635770
#
#    gross_capital_formation    imports  gross_saving  industry  manufacturing  \
# 0                -1.043266  -9.755901           NaN  6.712677       8.539505
# 1                14.196934   3.909215           NaN  7.072028       7.279412
# 2                 7.415240   3.391989           NaN  9.447275       9.458533
# 3                10.403833   3.379743           NaN  6.479270       6.914751
# 4                10.382610 -11.056208           NaN  4.525377       0.928715
#
#     population   service   pm
# ...

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="gdp_growth",data=country3,hue="pm")
plt.title("Comparision of GDP Growth with Prime Minister's tenure")
plt.show()

# %% [markdown]
# Term of Rao as PM started on a almost collapsed economy due to current account deficit and foreigh reserve meltdown due to payment deficit. The economic policies in that age along with Manmohan as FM laid foundation for gradual growth and future growth.
#
# Term of Manmohan Singh as PM started on a positive note at the end of Vajpayee govt. This term saw growth other than global recession during 2008 and its following impact.
#
# Term of Modi started on a high however saw gradual slowdown due to high inflation in on global slowdown. The pandemic has reduced the gdp growth to negative in a long term this is the lowest ever.

# %%
plt.figure(figsize=(17,6))
plt.xticks(rotation=90)
sn.barplot(x="index",y="agriculture",data=country3,hue="pm")
plt.title("Agricultural Growth Against Prime Minister's Tenures")
plt.show()

# %% [markdown]
# The Agriculture sector growth rate has been high during Indira Gandhi's tearm as PM,especially the first term. This is mostly due to the post 1960 measures rlated to green revolution followed by good monsoon. There are dips during war and drought period.
#
# The agriculture year on year growth rate has declined over period of times and doesnt shows considerable growth during both Manmohan and Modi term.

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="manufacturing",data=country3,hue="pm")
plt.title("Manufactoring Sector's Growth Against Prime Minister's Tenure")
plt.show()

# %% [markdown]
# Manufacturing secrtor's growth picked up well during Rao's term as FM which also had Manmohan as PM.
# This continued during vajpayee's term, improved and stabilized during manmohan's term as PM.
# Modi's term saw stability yet gradual decline which ended up with negative growth gate followed by pandemic.

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="service",data=country3,hue="pm")
plt.title("Service Sector's Growth Against Prime Minister's Tenure")
plt.show()

# %% [markdown]
# Service secrtor's started stable growth during Indira's term as PM which picked up in Rajiv's tearm with introduction of Information Technology into India in a good way with technocrat Sam Pitroda's support.
#
# This continued to do well across various PMs tenure till it made nose diove in 2020 on pandemic induced slowdown.

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="exports",data=country3,hue="pm")
plt.title("Export Growth Trend Against Prime Minister's Tenure")
plt.show()

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="imports",data=country3,hue="pm")
plt.title("Import Growth Trend Against Prime Minister's Tenure")
plt.show()

# %% [markdown]
# Exports and import has declined greatly during Modi's term which was visibly high in Manmohan's term as PM.

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="final_consumption",data=country3,hue="pm")
plt.title("Final Consumption Trend Against Prime Minister's Tenure")
plt.show()

# %% [markdown]
# The consumption has been on growing trend and stable especially on the rise since begining of 80s. Picked up better growth from 90s. has been ever growing since. This indicates the spending power of Indian consumer and which has been aiding the economy. The Pandemic sees hostoric drop in this also.

# %%
country3.groupby("pm")[["gdp_growth","agriculture","manufacturing","service","imports","exports"]].corr()
# Out:
#                       gdp_growth  agriculture  manufacturing   service  \
# pm
# 0      gdp_growth       1.000000     0.841715       0.613240  0.753819
#        agriculture      0.841715     1.000000       0.432442  0.445900
#        manufacturing    0.613240     0.432442       1.000000  0.176885
#        service          0.753819     0.445900       0.176885  1.000000
#        imports         -0.375784    -0.314547      -0.617404 -0.035402
#        exports          0.071258    -0.143565       0.337327  0.008485
# indira gdp_growth       1.000000     0.916113       0.018444  0.336928
#        agriculture      0.916113     1.000000      -0.217545  0.049814
#        manufacturing    0.018444    -0.217545       1.000000  0.305424
#        service          0.336928     0.049814       0.305424  1.000000
#        imports          0.284512     0.339698       0.021913  0.001042
#        exports         -0.141193    -0.122723      -0.339651 -0.012776
# ...

# %%
plt.figure(figsize=(16,8))
sn.heatmap(country3[country3["pm"]=="jln"][["gdp_growth",
                                            "agriculture","manufacturing","service","imports",
                                            "exports"]].corr(),annot=True)
plt.title("Heatmap Representation of GDP Growth Correlation durint PM: J L Nehru's Term")
plt.show()

# %%
plt.figure(figsize=(16,8))
sn.heatmap(country3[country3["pm"]=="lbs"][["gdp_growth",
                                            "agriculture","manufacturing","service","imports",
                                            "exports"]].corr(),annot=True)
plt.title("Heatmap Representation of GDP Growth Correlation durint PM: Lal Bahadur Shastry's Term")
plt.show()

# %%
plt.figure(figsize=(16,8))
sn.heatmap(country3[country3["pm"]=="indira"][["gdp_growth",
                                            "agriculture","manufacturing","service","imports",
                                            "exports"]].corr(),annot=True)
plt.title("Heatmap Representation of GDP Growth Correlation durint PM: Indira Gandhi's Term")
plt.show()

# %%
plt.figure(figsize=(16,8))
sn.heatmap(country3[country3["pm"]=="rajiv"][["gdp_growth",
                                            "agriculture","manufacturing","service","imports",
                                            "exports"]].corr(),annot=True)
plt.title("Heatmap Representation of GDP Growth Correlation durint PM: Rajiv Gandhi's Term")
plt.show()

# %%
plt.figure(figsize=(16,8))
sn.heatmap(country3[country3["pm"]=="rao"][["gdp_growth",
                                            "agriculture","manufacturing","service","imports",
                                            "exports"]].corr(),annot=True)
plt.title("Heatmap Representation of GDP Growth Correlation durint PM: Narasimha Rao's Term")
plt.show()

# %%
plt.figure(figsize=(16,8))
sn.heatmap(country3[country3["pm"]=="mms"][["gdp_growth",
                                            "agriculture","manufacturing","service","imports",
                                            "exports"]].corr(),annot=True)
plt.title("Heatmap Representation of GDP Growth Correlation durint PM: Manmohan Singh's Term")
plt.show()

# %%
plt.figure(figsize=(16,8))
sn.heatmap(country3[country3["pm"]=="modi"][["gdp_growth",
                                            "agriculture","manufacturing","service","imports",
                                            "exports"]].corr(),annot=True)
plt.title("Heatmap Representation of GDP Growth Correlation durint PM: Narendra Modi's Term")
plt.show()

# %% [markdown]
# The above heatmap representation is for gdp growth factor getting driven by various performance parameters.
# The analysis is very same as the periodic heat map corelation performed in previous reports.

# %%
condi_fm = [
    ((country3["index"].astype(np.int32)>=1950) & (country3["index"].astype(np.int32)<=1956)),
    ((country3["index"].astype(np.int32)>=1958) & (country3["index"].astype(np.int32)<=1962)),
    ((country3["index"].astype(np.int32)>=1963) & (country3["index"].astype(np.int32)<=1965)),
    ((country3["index"].astype(np.int32)>=1967) & (country3["index"].astype(np.int32)<=1969)),
    ((country3["index"].astype(np.int32)>=1970) & (country3["index"].astype(np.int32)<=1974)),
    ((country3["index"].astype(np.int32)>=1975) & (country3["index"].astype(np.int32)<=1977)),
    ((country3["index"].astype(np.int32)>=1980) & (country3["index"].astype(np.int32)<=1981)),
    ((country3["index"].astype(np.int32)>=1981) & (country3["index"].astype(np.int32)<=1984)),
    ((country3["index"].astype(np.int32)>=1985) & (country3["index"].astype(np.int32)<=1986)),
    ((country3["index"].astype(np.int32)>=1991) & (country3["index"].astype(np.int32)<=1996)),
    ((country3["index"].astype(np.int32)>=1998) & (country3["index"].astype(np.int32)<=2002)),
    ((country3["index"].astype(np.int32)>=2004) & (country3["index"].astype(np.int32)<=2008)),
    ((country3["index"].astype(np.int32)>=2009) & (country3["index"].astype(np.int32)<=2012)),
    ((country3["index"].astype(np.int32)>=2014) & (country3["index"].astype(np.int32)<=2018)),
    (country3["index"].astype(np.int32)>=2019)
]
val_fm = ["cdd","morarji","ttk","morarji","chavan","csub","r_venkat","mukherji","vps","mms","sinha","pc",
          "mukherji","jaitley","nirmala"]

# %%
country3["fin"]=np.select(condi_fm,val_fm)

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="gdp_growth",data=country3,hue="fin")
plt.title("Comparision of GDP Growth with Finance Minister's tenure")
plt.legend(loc=3)
plt.show()

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="agriculture",data=country3,hue="fin")
plt.title("Comparision of Agriculture Growth with Finance Minister's tenure")
plt.legend(loc=3)
plt.show()

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="service",data=country3,hue="fin")
plt.title("Comparision of Service Growth with Finance Minister's tenure")
plt.legend(loc=3)
plt.show()

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="manufacturing",data=country3,hue="fin")
plt.title("Comparision of Manufacturing Growth with Finance Minister's tenure")
plt.legend(loc=3)
plt.show()

# %%
plt.figure(figsize=(19,8))
plt.xticks(rotation=90)
sn.barplot(x="index",y="exports",data=country3,hue="fin")
plt.title("Comparision of Export Growth with Finance Minister's tenure")
plt.legend(loc=3)
plt.show()

# %% [markdown]
# Finance Minister based distribution, for inferences, visit the Corresponding Prime Minister related analysis.

# %%
plt.figure(figsize=(16,7))
sn.heatmap(country3.groupby(country3["fin"]=="mms")[["gdp_growth",
                                                     "agriculture","manufacturing","service","imports",
                                                     "exports"]].corr(), annot=True)
plt.title("Heatmap of orrelation with Manmohan Singh as Finance Minister")
# Out:
# Text(0.5, 1.0, 'Heatmap of orrelation with Manmohan Singh as Finance Minister')

# %%
plt.figure(figsize=(16,7))
sn.heatmap(country3.groupby(country3["fin"]=="pc")[["gdp_growth","agriculture","manufacturing","service",
                                                    "imports","exports"]].corr(),annot=True)
plt.title("Heatmap of orrelation with Chidambaram as Finance Minister")
# Out:
# Text(0.5, 1.0, 'Heatmap of orrelation with Chidambaram as Finance Minister')

# %%
plt.figure(figsize=(16,7))
sn.heatmap(country3.groupby(country3["fin"]=="chavan")[["gdp_growth","agriculture","manufacturing","service",
                                                        "imports","exports"]].corr(),annot=True)
plt.title("Heatmap of orrelation with Chavan as Finance Minister")
# Out:
# Text(0.5, 1.0, 'Heatmap of orrelation with Chavan as Finance Minister')

# %%
plt.figure(figsize=(16,7))
sn.heatmap(country3.groupby(country3["fin"]=="mukherji")[["gdp_growth","agriculture","manufacturing","service",
                                                          "imports","exports"]].corr(),annot=True)
plt.title("Heatmap of orrelation with Pranab Mukherjee as Finance Minister")
# Out:
# Text(0.5, 1.0, 'Heatmap of orrelation with Pranab Mukherjee as Finance Minister')

# %%
plt.figure(figsize=(16,7))
sn.heatmap(country3.groupby(country3["fin"]=="jaitley")[["gdp_growth","agriculture","manufacturing","service",
                                                         "imports","exports"]].corr(),annot=True)
plt.title("Heatmap of orrelation with Arun Jaitley as Finance Minister")
# Out:
# Text(0.5, 1.0, 'Heatmap of orrelation with Arun Jaitley as Finance Minister')

# %% [markdown]
# The Above Heatmap Correlation report indicates the various driving factors driving the economy during the term of various Finance Ministers.
#
# In Summary: Agriculture has driven the indian GDP for a long time after indepdndence. With emergence of other capabilities and industries, gradually the driving seat has been taken over by manufacturing, industry and service sector. With Agriculture influience gradually receding.
#
# Consumption has been increasing with time aiding the economy proportionally.

# %%
gdp_new=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\GDP_2020.csv")
meta=pd.read_csv("D:\MTech\Python\World_Bank_Data (2)\World_Bank_Data\meta.csv")

# %%
comm_cc=set(meta["Country Code"]) & set(gdp_new["Country Code"])
set(gdp_new["Country Code"]) - comm_cc
# Out:
# {'INX'}

# %%
gdp_new[gdp_new["Country Code"]=="INX"].index
# Out:
# Int64Index([110], dtype='int64')

# %%
gdp_new["reg"]="null"
gdp_new["ig"]="null"
for i in gdp_new.index.astype(np.int32):
    for j in meta.index.astype(np.int32):
        if gdp_new["Country Code"].iloc[i] == meta["Country Code"].iloc[j]:
            gdp_new["reg"].iloc[i] = meta["Region"].iloc[j]
            gdp_new["ig"].iloc[i] = meta["IncomeGroup"].iloc[j]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
gdp_new["reg"].unique()
# Out:
# array(['Latin America & Caribbean', nan, 'South Asia',
#        'Sub-Saharan Africa', 'Europe & Central Asia',
#        'Middle East & North Africa', 'East Asia & Pacific',
#        'North America', 'null'], dtype=object)

# %%
gdp["region"]=gdp_new["reg"].values
gdp["income"]=gdp_new["ig"].values
#gdp_latin=gdp[gdp["region"]=='Latin America & Caribbean']

# %%
year_s=[]
for m in year:
    year_s.append(str(m))

# %%
gdp_region=gdp.groupby("region")[year_s].mean()
gdp_income=gdp.groupby("income")[year_s].mean()

# %%
gdp_region=gdp_region.drop("null")
gdp_income=gdp_income.drop("null")

# %%
gdp_region.index, gdp_income.index
# Out:
# (Index(['East Asia & Pacific', 'Europe & Central Asia',
#         'Latin America & Caribbean', 'Middle East & North Africa',
#         'North America', 'South Asia', 'Sub-Saharan Africa'],
#        dtype='object', name='region'),
#  Index(['High income', 'Low income', 'Lower middle income',
#         'Upper middle income'],
#        dtype='object', name='income'))

# %%
gdp_average.fillna(0)
gdp["average"]=gdp_average.mean(axis=1)

# %%
gdp.head(2)
# Out:
#                                      1961          1962          1963  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  1.970954e+10  2.147872e+10  2.571501e+10
#
#                                      1964          1965          1966  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  2.351080e+10  2.679160e+10  2.913154e+10
#
#                                      1967          1968          1969  \
# Country Name
# Aruba                                 NaN           NaN           NaN
# Africa Eastern and Southern  3.015183e+10  3.285380e+10  3.771765e+10
#
#                                      1970  ...          2014          2015  \
# Country Name                               ...
# Aruba                                 NaN  ...  2.790849e+09  2.962905e+09
# Africa Eastern and Southern  4.028726e+10  ...  9.837490e+11  9.186470e+11
#
# ...

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,gdp_income.loc["High income"],label="High income",color="blue")
plt.plot(year,gdp_income.loc["Low income"],label="Low income",color="red")
plt.plot(year,gdp_income.loc["Lower middle income"],label="Lower middle income")
plt.plot(year,gdp_income.loc["Upper middle income"],label="Upper middle income")
plt.title("Income Group wise Economy 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# The Global Countries are categorised under 4 income groups.
# The trend shows rpid economic growth of the High Income Group countries. with an almost steep increase in the recent years.
# The high income group doesnt shows greatly impacted by the pandemic.
#
# The difference in growth rate of high income group and lower income group countries is very wide.
#
# Upper middle income group after sudden growth during early 2000s, appears to have bent towards lower rate and also shows impact due to pandemic.
#
# The Lower middle income group shows greatly impacted during global recession in the year 2008 and slow recovery after that.

# %%
plt.figure(figsize=(14,6))
plt.xticks(np.arange(1960,2021,2),rotation=90)
plt.plot(year,gdp_region.loc["East Asia & Pacific"],label="East Asia & Pacific")
plt.plot(year,gdp_region.loc["Europe & Central Asia"],label="Europe & Central Asia")
plt.plot(year,gdp_region.loc["Latin America & Caribbean"],label="Latin America & Caribbean")
plt.plot(year,gdp_region.loc["Middle East & North Africa"],label="Middle East & North Africa")
plt.plot(year,gdp_region.loc["North America"],label="North America",color="red")
plt.plot(year,gdp_region.loc["South Asia"],label="South Asia",color="blue")
plt.plot(year,gdp_region.loc["Sub-Saharan Africa"],label="Sub-Saharan Africa")
plt.title("Region wise wise Economy 1960 to 2020")
plt.legend()
plt.show()

# %% [markdown]
# The countries of the world are grouped into 7 Regions by world bank.
# North America stands out from all other regions in terms of the size of economy. USA is the major factor.
# The difference among regions is very wide.
#
# North america stands out with a wide margin from other 6 regions, other regions form a small band between Sub-saharan Africa and East Asia Pacific wide apart from north america. Sub saharan Africa is the most under performing region.
#
# South asia shows slow (compared to North America) but steady growth in the ecomomy.
#
# North america shows greatly impacted by 2008's recession and 2020 pandemic.

# %%
plt.figure(figsize=(14,6))
#sn.histplot(data=gdp,x="average",hue="income")
sn.kdeplot(data=gdp,x="average",hue="income")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='average', ylabel='Density'>

# %% [markdown]
# The distribution of GDP of Countrywise average has following inferences based on Income Groups.
#
# The Higher the income group, more the data is spread across Zero. This also means the Standard deviation increases with the increase in income group.
# The data is more right skewed for the higher income groups.
#
# This means the higher the group concentration of average GDP near Zero reduces and the possibility of having higher GDP is more with the possitivbe skewed data.
#
# On COntrary, Lower income groups are seen to have high density near zero.

# %%
plt.figure(figsize=(20,6))
sn.kdeplot(data=gdp,x="average",hue="region")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='average', ylabel='Density'>

# %% [markdown]
# In Continuation to the inferences made for income groups, the Regionally plotted data suggests similar inferences, the North America is right skewed and has lesser concentration near zero, while on other end Sub saharan and latin countries have more concentration near zero and lesser possibility of a higher right extreme gdp value

# %%
plt.figure(figsize=(14,6))
#sn.boxplot(gdp_region.loc["East Asia & Pacific"])
sn.boxplot(gdp_region.loc["East Asia & Pacific"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='East Asia & Pacific'>

# %% [markdown]
# East Asia and Pacific, distribution of yearly average of all regional country data suggests, 50% of density lies between 0.5 and 3.5 with a 25% possibility of scaling from 3.5 to 8.

# %%
plt.figure(figsize=(14,6))
sn.boxplot(gdp_region.loc["Europe & Central Asia"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Europe & Central Asia'>

# %% [markdown]
# Europe and Central Asia, distribution of yearly average of all regional country data suggests, 50% of density lies between 0. 8and 3.1 with a 25% possibility of scaling from 3.1 to 4.7.

# %%
plt.figure(figsize=(14,6))
sn.boxplot(gdp_region.loc["Latin America & Caribbean"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Latin America & Caribbean'>

# %% [markdown]
# Latin America and Carrebian, distribution of yearly average of all regional country data suggests, 50% of density lies between 0.15 and 0.8 with a 25% possibility of scaling from 0.8 to 1.6.

# %%
plt.figure(figsize=(14,6))
sn.boxplot(gdp_region.loc["Middle East & North Africa"])
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# Middle East and North Africa, distribution of yearly average of all regional country data suggests, 50% of density lies between 0.2 and 0.8 with a 25% possibility of scaling from 0.8 to 1.6.

# %%
plt.figure(figsize=(14,6))
sn.boxplot(gdp_region.loc["North America"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='North America'>

# %% [markdown]
# North America, distribution of yearly average of all regional country data suggests, 50% of density lies between 0.7 and 4.8 with a 25% possibility of scaling from 4.8 to 7.8.

# %%
plt.figure(figsize=(14,6))
sn.boxplot(gdp_region.loc["South Asia"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='South Asia'>

# %% [markdown]
# South Asia, distribution of yearly average of all regional country data suggests, 50% of density lies between 0.2 and 1.4 with a 25% possibility of scaling from 0.2 to 3. It also have outliers going till 5. This may be represented by few exceptional yers of growth by India, which has influenced the yearly average of rht region.

# %%
plt.figure(figsize=(14,6))
sn.boxplot(gdp_region.loc["Sub-Saharan Africa"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sub-Saharan Africa'>

# %% [markdown]
# Sub-Saharan Africa, distribution of yearly average of all regional country data suggests, 50% of density lies between 0.4 and 1.7 with a 25% possibility of scaling from 1.7 to 3.7.
